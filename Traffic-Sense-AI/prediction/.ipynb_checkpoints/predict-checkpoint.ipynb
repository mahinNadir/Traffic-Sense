# %%
# Importing YOLO from Ultralytics
from ultralytics import YOLO

# %%
# Loading Our Trained model
model = YOLO('../../models/Object-Detection/Last/model.pt')

# %%
# Getting the Predictions from model
result = model.predict('../../test-images/obj-det-3.jpg', conf=0.02)[0]
# Out:
# image 1/1 C:\Users\ulhaq\Desktop\TrafficSense\prediction\Object-Detection\..\..\test-images\obj-det-3.jpg: 640x640 18 bikes, 4 buss, 5 cars, 5 rickshaws, 1129.6ms
# Speed: 0.0ms preprocess, 1129.6ms inference, 11.4ms postprocess per image at shape (1, 3, 640, 640)

# %%
# Saving and returning Result Length
detected = len(result)
print(detected)
# Out:
# 32
