# %% [markdown]
# ### **Training Traffic Sense AI Model Using Yolo V5 Large (Weighted Model)**

# %% [markdown]
# **Cloning the YOLO v5 Model files**

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16003, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 16003 (delta 21), reused 20 (delta 13), pack-reused 15967
# Receiving objects: 100% (16003/16003), 14.66 MiB | 15.02 MiB/s, done.
# Resolving deltas: 100% (10983/10983), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.9/618.9 kB 37.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.2 MB/s eta 0:00:00

# %% [markdown]
# **Installing Ultralytics**

# %%
# !pip install ultralytics

# %% [markdown]
# **Mounting Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Unzipping the Dataset saved inside my Google Drive**

# %%
# !unzip -q /content/drive/MyDrive/TrafficSense/Object-Detection.zip

# %% [markdown]
# **Importing YOLO from Ultralytics which we have installed on above step**

# %%
# Importing YOLO from Ultralytics
from ultralytics import YOLO

# %% [markdown]
# **Now using YOLO v5 Large Weighted Model**

# %% [markdown]
# This model is balanced in terms of Detection so this will be a good choice if we wanted to detect all vehicles

# %%
# Importing YOLO V5 Model - K Version
model = YOLO("yolov5l.pt")
# Out:
# PRO TIP 💡 Replace 'model=yolov5l.pt' with new 'model=yolov5lu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100%|██████████| 102M/102M [00:06<00:00, 16.9MB/s]

# %% [markdown]
# **Training our Model (Fine Tuning)**

# %%
# Now Training our Model for Object aka vehicles detection
results = model.train(data='/content/yolov5/data/custom_data.yaml', epochs=100, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.195 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...
